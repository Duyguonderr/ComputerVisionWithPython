# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('data/indir.jfif')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=268x188 at 0x1A71D259898>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (188, 268, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (188, 268, 3)

# %%
# R G B

# RED CHANNEL VALUES  0 no red,pure black -255 full pure red
plt.imshow(pic_red[:,:,0],cmap='gray') #closer, more red

# %%
plt.imshow(pic_red[:,:,1],cmap='gray') #green

# %%
plt.imshow(pic_red[:,:,2],cmap='gray') #blue

# %%
#GREEN CHANNEL
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
#BLUE CHANNEL
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (188, 268, 3)

# %%
pic_red[:,:,1].shape
# Out:
# (188, 268)

# %%
pic_red[:,:,2].shape
# Out:
# (188, 268)
