# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
# cv2 automatcially reads it in directly as numpy array
img = cv2.imread('indir.jfif')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread('wrong/path/doesnot/fldsfldd.jpg')

# %%
# ıf it returns NoneType, then it is wrong path.
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('indir.jfif')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[61, 91, 92],
#         [60, 90, 91],
#         [60, 90, 91],
#         ...,
#         [36, 74, 62],
#         [36, 74, 62],
#         [36, 74, 62]],
#
#        [[60, 90, 91],
#         [60, 90, 91],
#         [59, 90, 91],
#         ...,
#         [36, 74, 62],
#         [36, 74, 62],
#         [36, 74, 62]],
#
#        [[60, 90, 91],
#         [59, 89, 90],
#         [58, 89, 90],
#         ...,
#         [37, 75, 63],
#         [37, 75, 63],
#         [37, 75, 63]],
#
#        ...,
#
#        [[20, 86, 57],
#         [22, 88, 59],
#         [26, 90, 61],
#         ...,
#         [18, 64, 45],
#         [18, 64, 45],
#         [18, 64, 45]],
#
#        [[21, 85, 56],
#         [23, 87, 58],
#         [26, 90, 61],
#         ...,
#         [18, 64, 45],
#         [18, 64, 45],
#         [16, 65, 45]],
#
#        [[23, 84, 56],
#         [25, 86, 58],
#         [27, 88, 60],
#         ...,
#         [18, 64, 45],
#         [16, 65, 45],
#         [16, 65, 45]]], dtype=uint8)

# %%
img.shape
# Out:
# (188, 268, 3)

# %%
plt.imshow(img)

# %%
#MATPLOTLIB --> RGB = RED GREEN BLUE
#OPENCV --> BGR = BLUE GREEN RED

# %%
fixed_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_img)

# %%
img_gray= cv2.imread('indir.jfif', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (188, 268)

# %%
plt.imshow(img_gray)

# %%
#color maps according to gray scale
plt.imshow(img_gray,cmap = 'gray')

# %%
#scaling
plt.imshow(fixed_img)

# %%
fixed_img.shape
# Out:
# (188, 268, 3)

# %%
new_img = cv2.resize(fixed_img,(100,100))

# %%
plt.imshow(new_img)

# %%
# make whole image 50% smaller
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fixed_img,(0,0),fixed_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (94, 134, 3)

# %%
#flip images
new_img = cv2.flip(fixed_img,0)
plt.imshow(new_img)

# %%
#save an img file
type(fixed_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg',fixed_img)
# Out:
# True

# %%
fig = plt.figure(figsize= (2,2))
ax = fig.add_subplot(111)
ax.imshow(fixed_img)
